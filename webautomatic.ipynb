# %%
# ============================================================= #
# ======== 2023 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# ======== 2023 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# ======== 2023 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# ============================================================= #

from selenium .webdriver .common .action_chains import ActionChains ;from selenium .webdriver .support .ui import WebDriverWait;from selenium .webdriver .common .keys import Keys;from selenium .webdriver .support import expected_conditions as EC ; import undetected_chromedriver as uc ; import time ,win32clipboard ,pyperclip ,codecs ,zipfile ,shutil ,os ;from datetime import datetime ;from PIL import Image ;from io import BytesIO ;import pandas as pd ;import base64 as ______;import marshal as ____;import zlib as __________;from cryptography.fernet import Fernet;import base64 ; from func_webautomatic.iIIiliiiiiIIlIli.iIIiliiiiiIIlIli import OO0O00O0O00O00OO0 , O0O00OOO0OOOO000O

class tool :

  # --- เปิด Chrome
  def open_web_chrome ( part_profile , delay_web=5 , show_img=True , headless_windows=False , extension =[] , proxy = [] , browser_executable_path_setup = None , driver_executable_path_setup = None , version_main_setup = None , user_multi_procs_setup = False ) :
    
    '''
      # !! หากเปิด GoogleChrome ไม่ได้ ให้ทำตามวิธีด้านล่าง

      1.โหลดไฟล์นี้ครับ ลิงค์ดาวน์โหลด : https://drive.google.com/file/d/1Uy2sVQkiexDpizQ-pnp5lV0WBybHPD3O/view?usp=sharing
      2.แตกไฟล์จะได้โฟรเดอร์ชื่อ chrome และนำโฟรเดอร์ชื่อ chrome ไปวางไว้ที่ Drive C: 
      3.เสร็จแล้วใช้ฟังก์ชั่น tool.open_web_chrome เหมือนเดิม 
      4.ตั้งค่า parameter ตามด้านล่าง

        driver = tools.open_web_chrome ( 
            
            'กำหนดตำแหน่งโฟรเดอร์เก็บโปรไฟล์' ,
            delay_web=5 , 
            show_img=True , 
            headless_windows=False , 
            extension =[] , 
            proxy = [] , 
            
            browser_executable_path_setup = r'C:\chrome\chrome.exe' , 
            driver_executable_path_setup = r'C:\chrome\chromedriver.exe' , 
            version_main_setup = 102 , 

            user_multi_procs_setup = False
          
        ) 

    '''
    return OO0O00O0O00O00OO0.OO0O0OOOO0OOOOOO0 (part_profile , delay_web, show_img, headless_windows, extension , proxy , browser_executable_path_setup , driver_executable_path_setup , version_main_setup , user_multi_procs_setup )

  # --- แสดงข้อมูล attribute จ่าก element
  def print_attribute ( element_data , attribute , print_all=True ) :
    return OO0O00O0O00O00OO0.OO0OO0O00O00O0000 (element_data , attribute , print_all)

  # --- แสดงข้อมูล text จ่าก element
  def print_text ( element_data , print_all=True ) :
    return OO0O00O0O00O00OO0.O00OO00O000O0O000 (element_data , print_all)

  # --- แปลงข้อมูล attribute  จ่าก element เป็น list
  def convert_attribute_to_list ( element_data , attribute  ):
    return OO0O00O0O00O00OO0.OO0O0OO0O0O0O00O0 ( element_data , attribute )
  
  # --- แปลงข้อมูล text  จ่าก element เป็น list
  def convert_text_to_list ( element_data  ):
    return OO0O00O0O00O00OO0.OOO0O0OOOOOO0000O ( element_data )

  # --- เลื่อนสกอบาร์ไม่จำกัด
  def infinite_scroll_bar( driver , wait_to_load=3 , timeout=5 ) :
    return OO0O00O0O00O00OO0.O00OO0OOO00OO00O0(driver , wait_to_load, timeout)

  # --- ดึงความสูงสกอบาร์
  def get_scroll_height( driver ) :
    return OO0O00O0O00O00OO0.O0OOOOO0O00OO0O0O( driver )

class webautomatic :

  # --- เข้าหน้าเว็บ
  def goto_web( driver , url , clear_ctrl_f5=False , wait_to_load=5 ) :
    return O0O00OOO0OOOO000O.O00OO0O0OOO00OO00(driver , url , clear_ctrl_f5, wait_to_load)
  
  # --- ค้นหา Text
  def find_text_by_xpath (driver ,text ,timeout =0.5 ,tag =['div','span','a','button']):
    return O0O00OOO0OOOO000O.O0OOOO000O0O0O000 (driver ,text ,timeout ,tag )

  # --- ค้นหา Text หลายตำแหน่ง
  def find_text_by_xpath_muti (driver ,text ,timeout =0.5 ,tag =['div','span','a','button']):
    return O0O00OOO0OOOO000O.O0O00OOO00O00OO00 (driver ,text ,timeout ,tag )

  # --- ค้นหา Text แบบ contains
  def find_text_contains_by_xpath ( driver , text , timeout=0.5 , tag=['div','span','a','button']  ):
    return O0O00OOO0OOOO000O.O0O000O0OO000OO0O (driver , text , timeout, tag)

  # --- ค้นหา Text แบบ contains หลายตำแหน่ง
  def find_text_contains_by_xpath_muti ( driver , text , timeout=0.5 , tag=['div','span','a','button']  ):
    return O0O00OOO0OOOO000O.O0OOO000O0OO0OOOO (driver , text , timeout, tag)

  # --- ค้นหา attribute
  def find_attribute_by_xpath (driver ,attribute =[[]],tag =['div','span','a','button'],timeout =0.5 ):
    return O0O00OOO0OOOO000O.OO00O0O0O000000OO (driver ,attribute ,tag ,timeout )

  # --- ค้นหา attribute หลายตำแหน่ง
  def find_attribute_by_xpath_muti ( driver , attribute=[[]]  , tag=['div','span','a','button']  , timeout=0.5  ):
    return O0O00OOO0OOOO000O.O00O00OO00OO00O0O (driver , attribute, tag  , timeout)

  # --- ค้นหา attribute แบบ contains
  def find_attribute_contains_by_xpath ( driver , attribute=[[]]  , tag=['div','span','a','button']  , timeout=0.5  ) :
    return O0O00OOO0OOOO000O.OOO0O00OO0O00OOOO (driver , attribute, tag  , timeout)

  # --- ค้นหา attribute แบบ contains หลายตำแหน่ง
  def find_attribute_contains_by_xpath_muti ( driver , attribute=[[]]  , tag=['div','span','a','button']  , timeout=0.5  ):
    return O0O00OOO0OOOO000O.O0OO0OO0O0OOOOOOO (driver , attribute, tag , timeout)

  # --- ค้นหา Xpath แบบ Custom
  def find_custom_xpath ( driver , xpath ='' , timeout =0.5 ):
    return O0O00OOO0OOOO000O.OO00O000OOO000OO0 (driver , xpath , timeout )

  # --- ค้นหา Xpath หลายตำแหน่ง แบบ Custom
  def find_custom_xpath_muti ( driver , xpath ='' , timeout =0.5 ):
    return O0O00OOO0OOOO000O.O0O0O00O00O0OOO0O (driver , xpath , timeout )

  # --- คลิก element
  def click_by_xpath ( driver , element_path , count=1 , delay=0.1 , mode=1  ) :
    return O0O00OOO0OOOO000O.OO0OOO0O0OOO0OO0O (driver , element_path , count, delay, mode)

  # --- คลิก แบบ Muti element
  def click_muti_by_xpath ( driver , element_path=[] , count=1 , delay=0.1 , mode=1  ):
    return O0O00OOO0OOOO000O.O0O000O0OO0OO0000 (driver , element_path, count, delay, mode)

  # --- เคลีย input
  def clear_input_by_xpath ( driver , element_path , mode=1 ):
    return O0O00OOO0OOOO000O.O000OOOO0O000O00O (driver , element_path , mode)
  
  # --- พิมข้อความ input
  def insert_input_by_xpath ( driver  , text , element_path , mode=1 ):
    return O0O00OOO0OOOO000O.OOO0O000OO000O000 (driver  , text , element_path , mode)

  # --- เลื่อน Scroll ตาม Tag 
  def scroll_to_element_by_xpath( driver , element_path , mode=1 ) :
    return O0O00OOO0OOOO000O.O0OO00O00OO0O0OO0(driver , element_path , mode)

  # --- เลื่อน Target ตาม Tag
  def move_to_element_by_xpath( driver , element_path ) :
    return O0O00OOO0OOOO000O.OOOO0000O00OOOOO0( driver , element_path )
  
  # --- เลื่อน Target ตาม Tag แบบ หลายๆ Tag
  def move_to_element_list_by_xpath( driver , element_list ) :
    return O0O00OOO0OOOO000O.OO0OOO0O0O000OOOO( driver , element_list )

  # --- Drop ภาพลง element
  def drop_file_by_xpath( driver , element_path , path_file , mode=1 ):
    return O0O00OOO0OOOO000O.O0OOOO0OOO00O00OO(driver , element_path , path_file , mode)

  # --- ลากและวาง Element
  def drag_and_drop_by_xpath( driver , element_first , element_last  ):
    return O0O00OOO0OOOO000O.O0OO0O000O00O0OO0( driver , element_first , element_last  )
  
  # --- เลื่อน Scroll ทั้งหน้า
  def scroll_max( driver ) :
    return O0O00OOO0OOOO000O.OO00OOO0OO00O00O0( driver )
  
  # --- เลื่อน Scroll กำหนด % ความสูง
  def scroll_custom( driver , target ) :
      return O0O00OOO0OOOO000O.OO0O0OOO00O00O0O0( driver , target )
        
  #---- จับเวลา
  def time_out( min , sec ):
    return O0O00OOO0OOOO000O.O0OO00O000O0OO000( min , sec  )
  
  #---- คลิก alert box
  def alert_box (driver ):
    return O0O00OOO0OOOO000O.O0OO00OO000O00000(driver)
# Out:
# # ============================================================= #
# # ============================================================= #
# # ======== 2022 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# # ======== 2022 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# # ======== 2022 เขียนโค้ดง่ายนิดเดียว , © All Right Reserved ======= #
# # ============================================================= #
# # ============ พัฒนา Code โดย : เพจเขียนโค้ดง่ายนิดเดียว =========== #
# # ============ พัฒนา Code โดย : เพจเขียนโค้ดง่ายนิดเดียว =========== #
# # ============ พัฒนา Code โดย : เพจเขียนโค้ดง่ายนิดเดียว =========== #
# # ============================================================= #
# # ========== https://www.facebook.com/100085494420593 ========= #
# # ========== https://www.facebook.com/100085494420593 ========= #
# # ========== https://www.facebook.com/100085494420593 ========= #
# # ============================================================= #
# ...

# %%
tool.open_web_chrome( r'D:\StudyProgramming\New folder' , delay_web=5 , show_img=2 , headless_windows=False )
# Out:
# Message: unknown error: cannot connect to chrome at 127.0.0.1:51235
# from session not created: This version of ChromeDriver only supports Chrome version 117
# Current browser version is 116.0.5845.188
# Stacktrace:
# 	GetHandleVerifier [0x00FCCEB3+45171]
# 	(No symbol) [0x00F59101]
# 	(No symbol) [0x00E4BE1D]
# 	(No symbol) [0x00E74441]
# 	(No symbol) [0x00E73C2A]
# 	(No symbol) [0x00E6D73C]
# 	(No symbol) [0x00E6D56F]
# 	(No symbol) [0x00EA1AA6]
# 	(No symbol) [0x00EA163C]
# 	(No symbol) [0x00E9AE46]
# 	(No symbol) [0x00E7675E]
# 	(No symbol) [0x00E778FD]
# 	GetHandleVerifier [0x012854B9+2897529]
# 	GetHandleVerifier [0x012CDC6B+3194411]
# 	GetHandleVerifier [0x012C7A41+3169281]
# 	GetHandleVerifier [0x01056130+606960]
# 	(No symbol) [0x00F62E7C]
# 	(No symbol) [0x00F5F008]
# 	(No symbol) [0x00F5F12F]
# 	(No symbol) [0x00F51827]
# 	BaseThreadInitThunk [0x768AFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77637B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77637AEE+238]
# False
